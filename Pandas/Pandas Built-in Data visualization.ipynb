# %% [markdown]
# # Python for data visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('/Users/asheshlalshrestha/Desktop/Datanal/Dataset/df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('/Users/asheshlalshrestha/Desktop/Datanal/Dataset/df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['a'].plot(kind='area')
# Out:
# <Axes: >

# %%
df2['a'].plot.area(alpha =0.5)
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked = True)
# Out:
# <Axes: >

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.line(x=df1.index,y='B', figsize =(12,3))
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A',y='B', c='C')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*100, c='C')
# Out:
# /Users/asheshlalshrestha/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['A','B'])

# %%
df
# Out:
#             A         B
# 0    1.765975 -0.723754
# 1   -1.151929 -0.171878
# 2   -1.594069  0.359016
# 3   -0.551433 -0.101623
# 4    1.020791  0.256156
# ..        ...       ...
# 995 -0.417436 -0.283230
# 996  0.605823 -0.234538
# 997  1.690138  2.243856
# 998 -0.344965 -0.996502
# 999 -1.191004  0.901288
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='A',y='B',gridsize=30,cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df['A'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
#Exercise

# %%
df3 = pd.read_csv('/Users/asheshlalshrestha/Desktop/Datanal/Dataset/df3')

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.describe()
# Out:
#                 a           b           c           d
# count  500.000000  500.000000  500.000000  500.000000
# mean     0.485294    0.504049    0.506183    0.517390
# std      0.290985    0.272966    0.295953    0.293166
# min      0.000410    0.010649    0.000575    0.002851
# 25%      0.225024    0.270928    0.243931    0.281738
# 50%      0.479164    0.510915    0.507474    0.533044
# 75%      0.755088    0.728839    0.769660    0.788106
# max      0.998111    0.996740    0.999709    0.989946

# %%
df3.plot.scatter(x='b',y='a',s=50,c='red',figsize=(12,3))
# Out:
# <Axes: xlabel='b', ylabel='a'>

# %%
df3['a'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins=20,alpha = 0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df3[['a','b']].plot.box()
# Out:
# <Axes: >

# %%
df3['d'].plot.kde(lw=5,ls='--')
# Out:
# <Axes: ylabel='Density'>

# %%
df3.ix[0:30]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9b/q0txn0fd5qj57z36hsjf2yxh0000gn/T/ipykernel_9555/921862409.py in ?()
# ----> 1 df3.ix[0:30]
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
