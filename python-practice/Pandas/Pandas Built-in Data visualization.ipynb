# %% [markdown]
# # Python for data visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('/Users/asheshlalshrestha/Desktop/Datanal/python-practice/Dataset/df1',index_col=0)

# %%
df1.drop_duplicates()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('/Users/asheshlalshrestha/Desktop/Datanal/python-practice/Dataset/df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2['a'].plot(kind='area')
# Out:
# <Axes: >

# %%
df2['a'].plot.area(alpha =0.5)
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked = True)
# Out:
# <Axes: >

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.line(x=df1.index,y='B', figsize =(12,3))
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A',y='B', c='C')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*100, c='C')
# Out:
# /Users/asheshlalshrestha/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['A','B'])

# %%
df
# Out:
#             A         B
# 0    0.121748 -0.561225
# 1    0.040563 -0.677395
# 2   -0.290647  0.384452
# 3   -0.227365 -0.186066
# 4   -0.001157 -0.490343
# ..        ...       ...
# 995 -0.388192 -0.734098
# 996 -0.631435 -1.267376
# 997  1.249227  0.864437
# 998 -0.030004  0.863161
# 999 -0.904476  0.200495
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='A',y='B',gridsize=30,cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df['A'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
#Exercise

# %%
df3 = pd.read_csv('/Users/asheshlalshrestha/Desktop/Datanal/Dataset/df3')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df3 = pd.read_csv('/Users/asheshlalshrestha/Desktop/Datanal/Dataset/df3')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df3.head()

# %%
df3.info()

# %%
df3.describe()

# %%
df3.plot.scatter(x='b',y='a',s=50,c='red',figsize=(12,3))

# %%
df3['a'].plot.hist(bins=10)

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins=20,alpha = 0.5)

# %%
df3[['a','b']].plot.box()

# %%
df3['d'].plot.kde(lw=5,ls='--')

# %%
df3.ix[0:30]
